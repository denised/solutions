# %%
from tools import solution_xls_extract as sxe
from tools import vma_xls_extract as vxe
from pathlib import Path
import sys
import pandas as pd
import openpyxl

# %%
excelfile = Path("C:\\Users\\drape\\Desktop\\Glass_RRS_Model_Residential-Nov19.xlsm")
outdir = Path("C:\\Users\drape\\Desktop")

# %%
import importlib
importlib.reload(sxe)
# Out:
# <module 'tools.solution_xls_extract' from 'C:\\Projects\\Project Drawdown\\solutions\\tools\\solution_xls_extract.py'>

# %%
sxe.output_solution_python_file(outputdir=outdir, xl_filename=str(excelfile))
# Out:
# C:\ProgramData\Miniconda3\envs\dev_try2\lib\site-packages\openpyxl\reader\drawings.py:59: UserWarning: wmf image format is not supported so the image is being dropped
#   warn(msg)
# C:\ProgramData\Miniconda3\envs\dev_try2\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# C:\ProgramData\Miniconda3\envs\dev_try2\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# C:\ProgramData\Miniconda3\envs\dev_try2\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# C:\Projects\Project Drawdown\solutions\tools\solution_xls_extract.py:1831: UserWarning: formula "F192/10^9*10^6" in 5:327 not recognised - using value
#   warnings.warn(f'formula "{formula}" in {col}:{str(row)} not recognised - using value')
# ...

# %%
# %debug
# Out:
# > c:\programdata\miniconda3\envs\dev_try2\lib\site-packages\pandas\core\indexes\base.py(4297)__getitem__()
#    4295         if is_scalar(key):
#    4296             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4297             return getitem(key)
#    4298
#    4299         if isinstance(key, slice):
#
# ipdb> up 5
# *** all frames above hidden
# ipdb> up
# > c:\projects\project drawdown\solutions\tools\solution_xls_extract.py(1399)extract_source_data()
#    1397             # the source_name from Excel, because some solutions like Composting have duplicate
#    1398             # column names and pd.read_excel automatically appends ".1" and ".2" to make them unique.
# -> 1399             source_name = region_data[region].columns[col - 2]   # "-2" translates from excel column # to df column #
#    1400             filename = sources.get(source_name, None)
#    1401             if source_name is not None and filename is not None:
#
# ipdb> usecols
# 'B:M'
# ipdb> region
# ...

# %%
sxe.co("E")
# Out:
# 5

# %%
238+66
# Out:
# 304
